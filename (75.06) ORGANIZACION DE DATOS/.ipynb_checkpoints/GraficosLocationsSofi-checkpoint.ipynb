# %%
import numpy as np
import pandas as pd
import shapefile as shp
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import squarify as sq

# %%
sns.set(style='whitegrid', palette='pastel', color_codes=True) 
sns.mpl.rc('figure', figsize=(10,6))

# %% [markdown]
# ## BOTH TRUE AND FALSE TWEETS

# %%
tweets = pd.read_csv('Tweets_locations.csv',encoding = 'latin-1')
tweets
# Out:
#          id keyword                                               text  \
# 0         1     NaN  Our Deeds are the Reason of this #earthquake M...
# 1         4     NaN             Forest fire near La Ronge Sask. Canada
# 2         5     NaN  All residents asked to 'shelter in place' are ...
# 3         6     NaN  13,000 people receive #wildfires evacuation or...
# 4         7     NaN  Just got sent this photo from Ruby #Alaska as ...
# ...     ...     ...                                                ...
# 7608  10869     NaN  Two giant cranes holding a bridge collapse int...
# 7609  10870     NaN  @aria_ahrary @TheTawniest The out of control w...
# 7610  10871     NaN  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611  10872     NaN  Police investigating after an e-bike collided ...
# 7612  10873     NaN  The Latest: More Homes Razed by Northern Calif...
#
#       text_len  target  target_bool location city country state
# ...

# %% [markdown]
# ## TRUE TWEETS

# %%
Rtweets = tweets[tweets['target_bool'] == True].drop(columns = ['target'])
Rtweets
# Out:
#          id keyword                                               text  \
# 0         1     NaN  Our Deeds are the Reason of this #earthquake M...
# 1         4     NaN             Forest fire near La Ronge Sask. Canada
# 2         5     NaN  All residents asked to 'shelter in place' are ...
# 3         6     NaN  13,000 people receive #wildfires evacuation or...
# 4         7     NaN  Just got sent this photo from Ruby #Alaska as ...
# ...     ...     ...                                                ...
# 7608  10869     NaN  Two giant cranes holding a bridge collapse int...
# 7609  10870     NaN  @aria_ahrary @TheTawniest The out of control w...
# 7610  10871     NaN  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611  10872     NaN  Police investigating after an e-bike collided ...
# 7612  10873     NaN  The Latest: More Homes Razed by Northern Calif...
#
#       text_len  target_bool location city country state
# 0           69         True      NaN  NaN     NaN   NaN
# ...

# %% [markdown]
# ## FALSE TWEETS

# %%
Ftweets = tweets[tweets['target_bool'] == False].drop(columns = ['target'])
Ftweets
# Out:
#          id  keyword                                               text  \
# 15       23      NaN                                     What's up man?
# 16       24      NaN                                      I love fruits
# 17       25      NaN                                   Summer is lovely
# 18       26      NaN                                  My car is so fast
# 19       28      NaN                       What a goooooooaaaaaal!!!!!!
# ...     ...      ...                                                ...
# 7581  10833  wrecked  @engineshed Great atmosphere at the British Li...
# 7582  10834  wrecked  Cramer: Iger's 3 words that wrecked Disney's s...
# 7584  10837      NaN  These boxes are ready to explode! Exploding Ki...
# 7587  10841      NaN                                 Sirens everywhere!
# 7593  10848      NaN  I just heard a really loud bang and everyone i...
#
#       text_len  target_bool location     city country state
# ...

# %%
tweets_loc = Rtweets.groupby(['target_bool']).agg({'country': 'count'})
tweets_loc
# Out:
#              country
# target_bool
# True             463

# %%
tweets_loc = tweets.groupby(['country', 'target_bool']).agg({'target_bool': 'count'})
tweets_loc.unstack().head(30)
# Out:
#               target_bool
# target_bool         False True
# country
# AFGHANISTAN           NaN   2.0
# ANTARCTICA            NaN   1.0
# ARGENTINA             5.0   5.0
# AUSTRALIA            24.0  29.0
# AZERBAIJAN            1.0   1.0
# BAHRAIN               NaN   1.0
# BARBADOS              3.0   1.0
# BELGIUM               1.0   1.0
# BOTSWANA              1.0   NaN
# BOUVET ISLAND         NaN   1.0
# BRAZIL                6.0   NaN
# BULGARIA              1.0   NaN
# CAMBODIA              NaN   1.0
# CAMEROON              NaN   1.0
# CANADA               40.0  37.0
# CHILE                 1.0   2.0
# CHINA                 7.0   3.0
# COLOMBIA              3.0   NaN
# COSTA RICA            2.0   NaN
# CUBA                  NaN   1.0
# CYPRUS                1.0   1.0
# DENMARK               NaN   1.0
# ECUADOR               2.0   1.0
# EGYPT                 1.0   3.0
# FINLAND               3.0   2.0
# FRANCE                7.0   3.0
# GEORGIA               9.0   5.0
# ...

# %%
Rtweets_loc = Rtweets.groupby(['country']).agg({'target_bool': 'count'})
Rtweets_loc
# Out:
#                 target_bool
# country
# AFGHANISTAN               2
# ANTARCTICA                1
# ARGENTINA                 5
# AUSTRALIA                29
# AZERBAIJAN                1
# ...                     ...
# UNITED KINGDOM           12
# UNITED STATES           105
# VENEZUELA                 4
# VIETNAM                   2
# ZIMBABWE                  1
#
# [75 rows x 1 columns]

# %%
tweets_loc = Ftweets.groupby(['country']).agg({'target_bool': 'count'})
tweets_loc['target_bool'].nlargest(40)
# Out:
# country
# UNITED STATES     71
# CANADA            40
# AUSTRALIA         24
# KENYA             19
# UNITED KINGDOM    18
# NIGERIA           15
# SOUTH AFRICA      14
# INDIA             13
# IRELAND           12
# INDONESIA         10
# GEORGIA            9
# JAPAN              9
# PHILIPPINES        8
# CHINA              7
# FRANCE             7
# BRAZIL             6
# SINGAPORE          6
# SWEDEN             6
# ARGENTINA          5
# PORTUGAL           5
# GERMANY            4
# JERSEY             4
# MALAYSIA           4
# NEW ZEALAND        4
# SAUDI ARABIA       4
# SWITZERLAND        4
# BARBADOS           3
# COLOMBIA           3
# FINLAND            3
# IRAQ               3
# JAMAICA            3
# MEXICO             3
# MOROCCO            3
# NEW CALEDONIA      3
# PANAMA             3
# PERU               3
# RUSSIA             3
# SPAIN              3
# COSTA RICA         2
# ECUADOR            2
# Name: target_bool, dtype: int64

# %% [markdown]
# ## TRUE TWEETS BY COUNTRY

# %%
Rtweets_country = Rtweets.groupby(['country']).agg({'target_bool': 'count'})
Rtweets_country.head(30).plot.barh(color = 'SkyBlue')

# %% [markdown]
# ## FALSE TWEETS BY COUNTRY

# %%
tweets_loc = Ftweets.groupby(['country']).agg({'target_bool': 'count'})
tweets_loc.head(30).plot.barh(color = 'DarkViolet')

# %% [markdown]
# ## TRUE TWEETS BY CITY

# %%
tweets_city = Rtweets.groupby(['city']).agg({'target_bool': 'count'})
tweets_city.head(30).plot.barh(color = 'SkyBlue')

# %% [markdown]
# ## FALSE TWEETS BY CITY

# %%
tweets_city = Ftweets.groupby(['city']).agg({'target_bool': 'count'})
tweets_city.head(30).plot.barh(color = 'DarkViolet')

# %% [markdown]
# ## TRUE TWEETS BY STATE

# %%
tweets_state = Rtweets.groupby(['state']).agg({'target_bool': 'count'})
tweets_state.head(30).plot.barh(color = 'SkyBlue')

# %% [markdown]
# ## FALSE TWEETS BY STATE

# %%
tweets_state = Ftweets.groupby(['state']).agg({'target_bool': 'count'})
tweets_state.head(30).plot.barh(color = 'DarkViolet')

# %% [markdown]
# ## ALL TWEETS

# %%
tweets_country = tweets.groupby(['country'], as_index = False ).agg({'target_bool': 'count'})
tweets_country.sort_values(by=['target_bool'], inplace=True, ascending=False )
auxc = tweets_country.head(15)
auxc
# Out:
#            country  target_bool
# 90   UNITED STATES          176
# 14          CANADA           77
# 61         NIGERIA           57
# 3        AUSTRALIA           53
# 36           INDIA           50
# 46           KENYA           30
# 89  UNITED KINGDOM           30
# 39         IRELAND           22
# 37       INDONESIA           22
# 77    SOUTH AFRICA           20
# 43           JAPAN           16
# 66     PHILIPPINES           16
# 26         GEORGIA           14
# 27         GERMANY           13
# 63        PAKISTAN           11

# %% [markdown]
# ## GRAPH TWEETS CONTRIES

# %%
tweets_colors = ['red', 'orangered', 'darkorange', 'goldenrod', 'gold', 'yellow', 'greenyellow', 'lawngreen', 'seagreen', 'turquoise', 'deepskyblue', 'royalblue', 'slateblue', 'indigo', 'deeppink']

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = auxc['target_bool'], label = auxc['country'], alpha=.6, color = tweets_colors)
plt.axis('off')
plt.title("Top 15 - Países con mas tweets ",fontsize=23,fontweight="bold")
plt.show()

# %% [markdown]
# ## GRAPH REAL TWEETS BY COUNTRY

# %%
Rtweets_country = Rtweets.groupby(['country'], as_index = False ).agg({'target_bool': 'count'})
Rtweets_country.sort_values(by=['target_bool'], inplace=True, ascending=False )
auxT = Rtweets_country.head(10)
auxT
# Out:
#            country  target_bool
# 71   UNITED STATES          105
# 49         NIGERIA           42
# 11          CANADA           37
# 27           INDIA           37
# 3        AUSTRALIA           29
# 28       INDONESIA           12
# 70  UNITED KINGDOM           12
# 37           KENYA           11
# 30         IRELAND           10
# 51        PAKISTAN            9

# %%
real_colors = ['rebeccapurple', 'darkorchid', 'mediumvioletred','hotpink', 'palevioletred', 'lightpink', 'darkorange', 'coral', 'sandybrown', 'peachpuff' ]

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = auxT['target_bool'], label = auxT['country'], alpha=.6, color = real_colors)
plt.axis('off')
plt.title("Top 10 - Países con mas tweets verdaderos  ",fontsize=23, fontweight="bold")
plt.show()

# %% [markdown]
# ## GRAPH FALSE TWEETS BY COUNTRY

# %%
Ftweets_country = Ftweets.groupby(['country'], as_index = False ).agg({'target_bool': 'count'})
Ftweets_country.sort_values(by=['target_bool'], inplace=True, ascending=False )
auxF = Ftweets_country.head(10)
auxF
# Out:
#            country  target_bool
# 69   UNITED STATES           71
# 8           CANADA           40
# 1        AUSTRALIA           24
# 33           KENYA           19
# 68  UNITED KINGDOM           18
# 44         NIGERIA           15
# 58    SOUTH AFRICA           14
# 24           INDIA           13
# 27         IRELAND           12
# 25       INDONESIA           10

# %%
false_colors = ['darkslateblue', 'slateblue', 'royalblue', 'deepskyblue','seagreen' ,'limegreen', 'lawngreen', 'yellowgreen', 'yellow', 'khaki' ]

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = aux['target_bool'], label = aux['country'], alpha=.6, color = false_colors)
plt.axis('off')
plt.title("Top 10 - Países con mas tweets falsos ",fontsize=23,fontweight="bold")
plt.show()

# %% [markdown]
# ## REAL TWEETS BY CITY

# %%
Rtweets_city = Rtweets.groupby(['city'], as_index = False ).agg({'target_bool': 'count'})
Rtweets_city.sort_values(by=['target_bool'], inplace=True, ascending=False )
aux1 = Rtweets_city.head(10)
aux1
# Out:
#               city  target_bool
# 269       NEW YORK           38
# 214         LONDON           35
# 391     WASHINGTON           34
# 258         MUMBAI           25
# 82         CHICAGO           19
# 216    LOS ANGELES           19
# 66         CALGARY           18
# 341  SAN FRANCISCO           16
# 376        TORONTO           12
# 240      MELBOURNE           11

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = aux1['target_bool'], label = aux1['city'], alpha=.6, color = real_colors)
plt.axis('off')
plt.title("Top 10 - Ciudades con mas tweets verdaderos ",fontsize=23,fontweight="bold")
plt.show()

# %% [markdown]
# ## FALSE TWEETS BY CITIES

# %%
Ftweets_city = Ftweets.groupby(['city'], as_index = False ).agg({'target_bool': 'count'})
Ftweets_city.sort_values(by=['target_bool'], inplace=True, ascending=False )
aux2 = Ftweets_city.head(10)
aux2
# Out:
#             city  target_bool
# 309     NEW YORK           90
# 248       LONDON           65
# 252  LOS ANGELES           35
# 74       CHICAGO           23
# 441        TEXAS           22
# 468   WASHINGTON           19
# 138      FLORIDA           17
# 15       ATLANTA           17
# 265   MANCHESTER           15
# 404      SEATTLE           15

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = aux2['target_bool'], label = aux2['city'], alpha=.6, color = false_colors)
plt.axis('off')
plt.title("Top 10 - Ciudades con mas tweets falsos ",fontsize=23,fontweight="bold")
plt.show()

# %% [markdown]
# ## TRUE TWEETS BY STATE

# %%
Rtweets_state = Rtweets.groupby(['state'], as_index = False ).agg({'target_bool': 'count'})
Rtweets_state.sort_values(by=['target_bool'], inplace=True, ascending=False )
aux3 = Rtweets_state.head(10)
aux3
# Out:
#          state  target_bool
# 36  WASHINGTON           32
# 3   CALIFORNIA           24
# 25    NEW YORK           15
# 30      OREGON           12
# 34       TEXAS           10
# 29    OKLAHOMA            9
# 4     COLORADO            8
# 14      KANSAS            6
# 7      FLORIDA            6
# 9       HAWAII            6

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = aux3['target_bool'], label = aux3['state'], alpha=.6, color = real_colors)
plt.axis('off')
plt.title("Top 10 - Estados de 'USA' con mas tweets verdaderos ",fontsize=23,fontweight="bold")
plt.show()

# %% [markdown]
# ## FALSE TWEETS BY STATE

# %%
Ftweets_state = Ftweets.groupby(['state'], as_index = False ).agg({'target_bool': 'count'})
Ftweets_state.sort_values(by=['target_bool'], inplace=True, ascending=False )
aux4 = Ftweets_state.head(10)
aux4
# Out:
#             state  target_bool
# 38     WASHINGTON           23
# 25       NEW YORK           21
# 34          TEXAS           21
# 1      CALIFORNIA           20
# 30   PENNSYLVANIA           11
# 27           OHIO            9
# 16  MASSACHUSETTS            6
# 2        COLORADO            6
# 5         GEORGIA            6
# 29         OREGON            6

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 4.5)

fig = plt.gcf()
fig.set_size_inches(16, 4.5)


sq.plot(sizes = aux4['target_bool'], label = aux4['state'], alpha=.6, color = false_colors)
plt.axis('off')
plt.title("Top 10 - Estados de 'USA' con mas tweets falsos",fontsize=23,fontweight="bold")
plt.show()

# %%
countrytweets = tweets.groupby(['country'], as_index = False ).agg({'target_bool': 'count'})
countrytweets.sort_values(by=['target_bool'], inplace=True, ascending=False )
TweetsInContries = countrytweets.head(15)
TweetsInContries
# Out:
#            country  target_bool
# 90   UNITED STATES          176
# 14          CANADA           77
# 61         NIGERIA           57
# 3        AUSTRALIA           53
# 36           INDIA           50
# 46           KENYA           30
# 89  UNITED KINGDOM           30
# 39         IRELAND           22
# 37       INDONESIA           22
# 77    SOUTH AFRICA           20
# 43           JAPAN           16
# 66     PHILIPPINES           16
# 26         GEORGIA           14
# 27         GERMANY           13
# 63        PAKISTAN           11

# %%
poblaciones = ['328200000', '195900000', '37590000', '1095351995', '24990000', '267700000', '66650000', '51390000', '4900000','212200000' , '83020000', '106700000', '46940000', '126500000', '60360000']
TweetsInContries['poblacion'] = poblaciones
TweetsInContries
# Out:
# <ipython-input-42-70537ad545dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TweetsInContries['poblacion'] = poblaciones
#            country  target_bool   poblacion
# 71   UNITED STATES          105   328200000
# 49         NIGERIA           42   195900000
# 11          CANADA           37    37590000
# 27           INDIA           37  1095351995
# 3        AUSTRALIA           29    24990000
# 28       INDONESIA           12   267700000
# 70  UNITED KINGDOM           12    66650000
# 37           KENYA           11    51390000
# 30         IRELAND           10     4900000
# 51        PAKISTAN            9   212200000
# 22         GERMANY            9    83020000
# 52     PHILIPPINES            8   106700000
# ...

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(20, 4.5)

fig = plt.gcf()
fig.set_size_inches(20, 4.5)


# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot( TweetsInContries['country'], TweetsInContries['target_bool'], color="red", marker="o" )
# set x-axis label
ax.set_xlabel("Countries",fontsize=10)
# set y-axis label
ax.set_ylabel("Tweets with their location",color="red",fontsize=14)



# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(TweetsInContries['country'],TweetsInContries['poblacion'] ,color="blue",marker="o")
ax2.set_ylabel("Poblacion en los paises",color="blue",fontsize=14)
plt.show()

# save the plot as a file
fig.savefig('two_different_y_axis_for_single_python_plot_with_twinx.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
